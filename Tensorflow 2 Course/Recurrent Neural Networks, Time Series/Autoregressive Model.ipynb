# %%
# Install TensorFlow
# !pip install -q tensorflow-gpu==2.0.0-beta1

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow is already loaded. Please restart the runtime to change versions.
# 2.6.0

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make the original data
series = np.sin(0.1*np.arange(200)) + np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T)
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (190, 10) Y.shape (190,)

# %%
### try autoregressive linear model
i = Input(shape=(T,))
x = Dense(1)(i)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.1),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/80
# 3/3 [==============================] - 0s 52ms/step - loss: 0.5326 - val_loss: 0.4398
# Epoch 2/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3797 - val_loss: 0.0944
# Epoch 3/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1128 - val_loss: 0.1395
# Epoch 4/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.1122 - val_loss: 0.0241
# Epoch 5/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0447 - val_loss: 0.0928
# Epoch 6/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0840 - val_loss: 0.0378
# Epoch 7/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0455 - val_loss: 0.0638
# Epoch 8/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0692 - val_loss: 0.0380
# Epoch 9/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0398 - val_loss: 0.0454
# Epoch 10/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0461 - val_loss: 0.0299
# Epoch 11/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0300 - val_loss: 0.0290
# Epoch 12/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0343 - val_loss: 0.0225
# Epoch 13/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0244 - val_loss: 0.0278
# Epoch 14/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0302 - val_loss: 0.0234
# Epoch 15/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0237 - val_loss: 0.0251
# Epoch 16/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0280 - val_loss: 0.0216
# Epoch 17/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0238 - val_loss: 0.0216
# Epoch 18/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0233 - val_loss: 0.0200
# Epoch 19/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0220 - val_loss: 0.0200
# Epoch 20/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0225 - val_loss: 0.0201
# Epoch 21/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0227 - val_loss: 0.0199
# Epoch 22/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0216 - val_loss: 0.0193
# Epoch 23/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0216 - val_loss: 0.0190
# Epoch 24/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0210 - val_loss: 0.0192
# Epoch 25/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0209 - val_loss: 0.0185
# Epoch 26/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0205 - val_loss: 0.0183
# Epoch 27/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0205 - val_loss: 0.0182
# Epoch 28/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0200 - val_loss: 0.0185
# Epoch 29/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0199 - val_loss: 0.0178
# Epoch 30/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.0177
# Epoch 31/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0200 - val_loss: 0.0178
# Epoch 32/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0195 - val_loss: 0.0172
# Epoch 33/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0201 - val_loss: 0.0175
# Epoch 34/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0188 - val_loss: 0.0178
# Epoch 35/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0195 - val_loss: 0.0168
# Epoch 36/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0186 - val_loss: 0.0167
# Epoch 37/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0184 - val_loss: 0.0168
# Epoch 38/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0183 - val_loss: 0.0165
# Epoch 39/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0184 - val_loss: 0.0167
# Epoch 40/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0178 - val_loss: 0.0162
# Epoch 41/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0179 - val_loss: 0.0161
# Epoch 42/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0177 - val_loss: 0.0162
# Epoch 43/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0176 - val_loss: 0.0160
# Epoch 44/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0174 - val_loss: 0.0159
# Epoch 45/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0173 - val_loss: 0.0164
# Epoch 46/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0174 - val_loss: 0.0158
# Epoch 47/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0171 - val_loss: 0.0158
# Epoch 48/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0173 - val_loss: 0.0156
# Epoch 49/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0169 - val_loss: 0.0156
# Epoch 50/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0167 - val_loss: 0.0157
# Epoch 51/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0166 - val_loss: 0.0162
# Epoch 52/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0175 - val_loss: 0.0155
# Epoch 53/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0170 - val_loss: 0.0160
# Epoch 54/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0174 - val_loss: 0.0162
# Epoch 55/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0173 - val_loss: 0.0157
# Epoch 56/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0168 - val_loss: 0.0164
# Epoch 57/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0168 - val_loss: 0.0155
# Epoch 58/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0165 - val_loss: 0.0153
# Epoch 59/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0170 - val_loss: 0.0152
# Epoch 60/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0160 - val_loss: 0.0153
# Epoch 61/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0164 - val_loss: 0.0167
# Epoch 62/80
# 3/3 [==============================] - 0s 22ms/step - loss: 0.0163 - val_loss: 0.0153
# Epoch 63/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0160 - val_loss: 0.0151
# Epoch 64/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0164 - val_loss: 0.0152
# Epoch 65/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0152 - val_loss: 0.0153
# Epoch 66/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0158 - val_loss: 0.0153
# Epoch 67/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0158 - val_loss: 0.0150
# Epoch 68/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0164 - val_loss: 0.0150
# Epoch 69/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0151 - val_loss: 0.0159
# Epoch 70/80
# 3/3 [==============================] - 0s 11ms/step - loss: 0.0161 - val_loss: 0.0151
# Epoch 71/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0158 - val_loss: 0.0150
# Epoch 72/80
# 3/3 [==============================] - 0s 13ms/step - loss: 0.0162 - val_loss: 0.0152
# Epoch 73/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0169 - val_loss: 0.0154
# Epoch 74/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0164 - val_loss: 0.0165
# Epoch 75/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.0165 - val_loss: 0.0160
# Epoch 76/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0163 - val_loss: 0.0163
# Epoch 77/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0154 - val_loss: 0.0153
# Epoch 78/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0165 - val_loss: 0.0154
# Epoch 79/80
# 3/3 [==============================] - 0s 12ms/step - loss: 0.0167 - val_loss: 0.0151
# Epoch 80/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0173 - val_loss: 0.0154

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1))[0,0] # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# first validation input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1))[0,0] # 1x1 array -> scalar
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
