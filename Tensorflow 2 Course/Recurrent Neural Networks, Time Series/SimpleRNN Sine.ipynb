# %%
# Install TensorFlow
# !pip install -q tensorflow-gpu==2.0.0-beta1

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.
# 2.6.0

# %%
from tensorflow.keras.layers import Input, SimpleRNN, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD, Adam

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# make the original data
series = np.sin(0.1*np.arange(200)) + np.random.randn(200)*0.1

# plot it
plt.plot(series)
plt.show()

# %%
### build the dataset
# let's see if we can use T past values to predict the next value
T = 10
D = 1
X = []
Y = []
for t in range(len(series) - T):
  x = series[t:t+T]
  X.append(x)
  y = series[t+T]
  Y.append(y)

X = np.array(X).reshape(-1, T, 1) # Now the data should be N x T x D
Y = np.array(Y)
N = len(X)
print("X.shape", X.shape, "Y.shape", Y.shape)
# Out:
# X.shape (190, 10, 1) Y.shape (190,)

# %%
### try autoregressive RNN model
i = Input(shape=(T, 1))
x = SimpleRNN(15, activation='relu')(i)
x = Dense(1)(x)
model = Model(i, x)
model.compile(
  loss='mse',
  optimizer=Adam(lr=0.001),
)

# train the RNN
r = model.fit(
  X[:-N//2], Y[:-N//2],
  epochs=80,
  validation_data=(X[-N//2:], Y[-N//2:]),
)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")
# Epoch 1/80
# 3/3 [==============================] - 1s 110ms/step - loss: 0.7490 - val_loss: 0.6285
# Epoch 2/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.6973 - val_loss: 0.5812
# Epoch 3/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.6520 - val_loss: 0.5366
# Epoch 4/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.6065 - val_loss: 0.4953
# Epoch 5/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.5637 - val_loss: 0.4564
# Epoch 6/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.5228 - val_loss: 0.4194
# Epoch 7/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4862 - val_loss: 0.3845
# Epoch 8/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.4500 - val_loss: 0.3519
# Epoch 9/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.4153 - val_loss: 0.3215
# Epoch 10/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.3846 - val_loss: 0.2924
# Epoch 11/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3553 - val_loss: 0.2659
# Epoch 12/80
# 3/3 [==============================] - 0s 14ms/step - loss: 0.3260 - val_loss: 0.2422
# Epoch 13/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.3017 - val_loss: 0.2208
# Epoch 14/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.2808 - val_loss: 0.2019
# Epoch 15/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.2605 - val_loss: 0.1853
# Epoch 16/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.2433 - val_loss: 0.1709
# Epoch 17/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2267 - val_loss: 0.1587
# Epoch 18/80
# 3/3 [==============================] - 0s 25ms/step - loss: 0.2128 - val_loss: 0.1485
# Epoch 19/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.2005 - val_loss: 0.1401
# Epoch 20/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1883 - val_loss: 0.1331
# Epoch 21/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1787 - val_loss: 0.1271
# Epoch 22/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.1691 - val_loss: 0.1216
# Epoch 23/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1604 - val_loss: 0.1165
# Epoch 24/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.1519 - val_loss: 0.1111
# Epoch 25/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1439 - val_loss: 0.1057
# Epoch 26/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1362 - val_loss: 0.1001
# Epoch 27/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.1281 - val_loss: 0.0947
# Epoch 28/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.1212 - val_loss: 0.0893
# Epoch 29/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1136 - val_loss: 0.0843
# Epoch 30/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1066 - val_loss: 0.0794
# Epoch 31/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0996 - val_loss: 0.0750
# Epoch 32/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0934 - val_loss: 0.0708
# Epoch 33/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0882 - val_loss: 0.0667
# Epoch 34/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0818 - val_loss: 0.0629
# Epoch 35/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0763 - val_loss: 0.0593
# Epoch 36/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0713 - val_loss: 0.0559
# Epoch 37/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0657 - val_loss: 0.0528
# Epoch 38/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0610 - val_loss: 0.0498
# Epoch 39/80
# 3/3 [==============================] - 0s 21ms/step - loss: 0.0567 - val_loss: 0.0470
# Epoch 40/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0523 - val_loss: 0.0444
# Epoch 41/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0486 - val_loss: 0.0419
# Epoch 42/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0452 - val_loss: 0.0396
# Epoch 43/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0423 - val_loss: 0.0375
# Epoch 44/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0395 - val_loss: 0.0356
# Epoch 45/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0369 - val_loss: 0.0340
# Epoch 46/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0350 - val_loss: 0.0324
# Epoch 47/80
# 3/3 [==============================] - 0s 20ms/step - loss: 0.0330 - val_loss: 0.0313
# Epoch 48/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0314 - val_loss: 0.0303
# Epoch 49/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0302 - val_loss: 0.0293
# Epoch 50/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0290 - val_loss: 0.0284
# Epoch 51/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0283 - val_loss: 0.0276
# Epoch 52/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0273 - val_loss: 0.0268
# Epoch 53/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0264 - val_loss: 0.0261
# Epoch 54/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0257 - val_loss: 0.0254
# Epoch 55/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0251 - val_loss: 0.0249
# Epoch 56/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0246 - val_loss: 0.0244
# Epoch 57/80
# 3/3 [==============================] - 0s 24ms/step - loss: 0.0240 - val_loss: 0.0240
# Epoch 58/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0235 - val_loss: 0.0236
# Epoch 59/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0230 - val_loss: 0.0232
# Epoch 60/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0223 - val_loss: 0.0227
# Epoch 61/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0217 - val_loss: 0.0222
# Epoch 62/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0208 - val_loss: 0.0217
# Epoch 63/80
# 3/3 [==============================] - 0s 19ms/step - loss: 0.0198 - val_loss: 0.0214
# Epoch 64/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0188 - val_loss: 0.0212
# Epoch 65/80
# 3/3 [==============================] - 0s 23ms/step - loss: 0.0184 - val_loss: 0.0211
# Epoch 66/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0179 - val_loss: 0.0210
# Epoch 67/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0175 - val_loss: 0.0206
# Epoch 68/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0168 - val_loss: 0.0203
# Epoch 69/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0164 - val_loss: 0.0201
# Epoch 70/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0159 - val_loss: 0.0199
# Epoch 71/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0156 - val_loss: 0.0198
# Epoch 72/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0154 - val_loss: 0.0197
# Epoch 73/80
# 3/3 [==============================] - 0s 17ms/step - loss: 0.0151 - val_loss: 0.0196
# Epoch 74/80
# 3/3 [==============================] - 0s 18ms/step - loss: 0.0149 - val_loss: 0.0196
# Epoch 75/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0148 - val_loss: 0.0196
# Epoch 76/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0146 - val_loss: 0.0195
# Epoch 77/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0145 - val_loss: 0.0194
# Epoch 78/80
# 3/3 [==============================] - 0s 15ms/step - loss: 0.0143 - val_loss: 0.0193
# Epoch 79/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0142 - val_loss: 0.0193
# Epoch 80/80
# 3/3 [==============================] - 0s 16ms/step - loss: 0.0141 - val_loss: 0.0193

# %%
# Plot loss per iteration
import matplotlib.pyplot as plt
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()

# %%
# "Wrong" forecast using true targets

validation_target = Y[-N//2:]
validation_predictions = []

# index of first validation input
i = -N//2

while len(validation_predictions) < len(validation_target):
  p = model.predict(X[i].reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  i += 1
  
  # update the predictions list
  validation_predictions.append(p)

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()

# %%
# Forecast future values (use only self-predictions for making future predictions)

validation_target = Y[-N//2:]
validation_predictions = []

# first validation input
last_x = X[-N//2] # 1-D array of length T

while len(validation_predictions) < len(validation_target):
  p = model.predict(last_x.reshape(1, -1, 1))[0,0] # 1x1 array -> scalar
  
  # update the predictions list
  validation_predictions.append(p)
  
  # make the new input
  last_x = np.roll(last_x, -1)
  last_x[-1] = p

# %%
plt.plot(validation_target, label='forecast target')
plt.plot(validation_predictions, label='forecast prediction')
plt.legend()
