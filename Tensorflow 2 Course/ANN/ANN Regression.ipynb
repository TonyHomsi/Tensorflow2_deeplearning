# %%
# Install TensorFlow
# !pip install -q tensorflow-gpu==2.0.0-beta1

try:
  # %tensorflow_version 2.x  # Colab only.
except Exception:
  pass

import tensorflow as tf
print(tf.__version__)
# Out:
# `%tensorflow_version` only switches the major version: 1.x or 2.x.
# You set: `2.x  # Colab only.`. This will be interpreted as: `2.x`.
#
#
# TensorFlow 2.x selected.
# 2.6.0

# %%
# Other imports
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
# Make the dataset
N = 1000
X = np.random.random((N, 2)) * 6 - 3 # uniformly distributed between (-3, +3)
Y = np.cos(2*X[:,0]) + np.cos(3*X[:,1])

# %%
# Plot it
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)
# plt.show()

# %%
# Build the model
model = tf.keras.models.Sequential([
  tf.keras.layers.Dense(128, input_shape=(2,), activation='relu'),
  tf.keras.layers.Dense(1)
])

# %%
# Compile and fit
opt = tf.keras.optimizers.Adam(0.01)
model.compile(optimizer=opt, loss='mse')
r = model.fit(X, Y, epochs=100)
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 1ms/step - loss: 0.9717
# Epoch 2/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.9529
# Epoch 3/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9153
# Epoch 4/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.9001
# Epoch 5/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8804
# Epoch 6/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8493
# Epoch 7/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7987
# Epoch 8/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.7526
# Epoch 9/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6679
# Epoch 10/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6470
# Epoch 11/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.6278
# Epoch 12/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5752
# Epoch 13/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5473
# Epoch 14/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5406
# Epoch 15/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5168
# Epoch 16/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5430
# Epoch 17/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5205
# Epoch 18/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4885
# Epoch 19/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5190
# Epoch 20/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5186
# Epoch 21/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4935
# Epoch 22/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5056
# Epoch 23/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5131
# Epoch 24/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4949
# Epoch 25/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4900
# Epoch 26/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4473
# Epoch 27/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4283
# Epoch 28/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4186
# Epoch 29/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.4238
# Epoch 30/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4179
# Epoch 31/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.4308
# Epoch 32/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3836
# Epoch 33/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3643
# Epoch 34/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3554
# Epoch 35/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.3385
# Epoch 36/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2922
# Epoch 37/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2750
# Epoch 38/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2593
# Epoch 39/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2859
# Epoch 40/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2289
# Epoch 41/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2089
# Epoch 42/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1674
# Epoch 43/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1548
# Epoch 44/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1368
# Epoch 45/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1252
# Epoch 46/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1030
# Epoch 47/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0975
# Epoch 48/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1054
# Epoch 49/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0627
# Epoch 50/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0458
# Epoch 51/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0540
# Epoch 52/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0510
# Epoch 53/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0298
# Epoch 54/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0253
# Epoch 55/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0231
# Epoch 56/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0503
# Epoch 57/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0298
# Epoch 58/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0269
# Epoch 59/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0201
# Epoch 60/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0140
# Epoch 61/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0119
# Epoch 62/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0134
# Epoch 63/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0147
# Epoch 64/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0167
# Epoch 65/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0142
# Epoch 66/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0137
# Epoch 67/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0145
# Epoch 68/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0188
# Epoch 69/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0126
# Epoch 70/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0126
# Epoch 71/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0091
# Epoch 72/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0101
# Epoch 73/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0127
# Epoch 74/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 75/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0084
# Epoch 76/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0083
# Epoch 77/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 78/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0063
# Epoch 79/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0084
# Epoch 80/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0077
# Epoch 81/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0080
# Epoch 82/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0088
# Epoch 83/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0161
# Epoch 84/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0257
# Epoch 85/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0122
# Epoch 86/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0069
# Epoch 87/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0089
# Epoch 88/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0110
# Epoch 89/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0222
# Epoch 90/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0289
# Epoch 91/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0258
# Epoch 92/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0107
# Epoch 93/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0109
# Epoch 94/100
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0074
# Epoch 95/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0090
# Epoch 96/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0097
# Epoch 97/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0137
# Epoch 98/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0103
# Epoch 99/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0092
# Epoch 100/100
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0060

# %%
# Plot the loss
plt.plot(r.history['loss'], label='loss')

# %%
# Plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# surface plot
line = np.linspace(-3, 3, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()

# %%
# Can it extrapolate?
# Plot the prediction surface
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(X[:,0], X[:,1], Y)

# surface plot
line = np.linspace(-5, 5, 50)
xx, yy = np.meshgrid(line, line)
Xgrid = np.vstack((xx.flatten(), yy.flatten())).T
Yhat = model.predict(Xgrid).flatten()
ax.plot_trisurf(Xgrid[:,0], Xgrid[:,1], Yhat, linewidth=0.2, antialiased=True)
plt.show()
